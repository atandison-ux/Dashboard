# %% [markdown]
# <a href="https://colab.research.google.com/github/atandison-ux/Dashboard/blob/main/Projeto1_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=200, n_features=100, noise=30)
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:, 0], y)
plt.show()

# %% [markdown]
# To install a Python library, you can use `pip install` with an exclamation mark `!` in front of it in a code cell. The `!` tells Colab that it's a shell command, not Python code.

# %%
# Example: installing the 'requests' library
# !pip install requests

# %% [markdown]
# If you need to install a specific version of a library, you can specify it like this:
# ```python
# !pip install library_name==1.2.3
# ```
#
# Or if you want to upgrade an already installed library:
# ```python
# !pip install --upgrade library_name
# ```
